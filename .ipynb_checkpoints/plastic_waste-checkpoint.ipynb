# %% [markdown]
# MINDEROO FOUNDATION
# <br>PLASTIC WASTE MAKERS INDEX
# <br>https://www.minderoo.org/plastic-waste-makers-index/data/flows/#/sankey/global/30

# %%
import pandas as pd
import json
import requests

# %%
url = "https://cdn.minderoo.org/content/apps/pwmi-sankey-chart/static/js/main.d577c6f3.chunk.js"

# %%
response = requests.get(url)
docs = response.text

# %%
start = '{"name":"China","column":3,"hover":{"Total Waste":25357.347,"rank":"1 / 178","per_capita":17.617542257259494,"per_capita_rank":"45 / 163"},"region":"Asia Pacific","node":10,"targetSum":25357,"sourceSum":0}'
end = '{"name":"Argentina","column":3,"hover":{"Total Waste":651.727,"rank":"30 / 178","per_capita":14.420090757347042,"per_capita_rank":"56 / 163"}'

# %%
docs[docs.find(start):docs.find(end)-1]
# Out:
# '{"name":"China","column":3,"hover":{"Total Waste":25357.347,"rank":"1 / 178","per_capita":17.617542257259494,"per_capita_rank":"45 / 163"},"region":"Asia Pacific","node":10,"targetSum":25357,"sourceSum":0},{"name":"United States","column":3,"hover":{"Total Waste":17192.281,"rank":"2 / 178","per_capita":51.94000863351773,"per_capita_rank":"9 / 163"},"region":"Americas","node":11,"targetSum":17192,"sourceSum":0},{"name":"India","column":3,"hover":{"Total Waste":5582.354,"rank":"3 / 178","per_capita":4.045171190832339,"per_capita_rank":"94 / 163"},"region":"Asia Pacific","node":12,"targetSum":5582,"sourceSum":0},{"name":"Japan","column":3,"hover":{"Total Waste":4710.928,"rank":"4 / 178","per_capita":37.24746816213011,"per_capita_rank":"18 / 163"},"region":"Asia Pacific","node":13,"targetSum":4711,"sourceSum":0},{"name":"United Kingdom","column":3,"hover":{"Total Waste":2892.859,"rank":"5 / 178","per_capita":42.61347345010812,"per_capita_rank":"13 / 163"},"region":"Greater Europe","node
# ...

# %%
{"name":"China",
 "column":3,
 "hover":
 {"Total Waste":25357.347,
  "rank":"1 / 178",
  "per_capita":17.617542257259494,
  "per_capita_rank":"45 / 163"},
 "region":"Asia Pacific",
 "node":10,
 "targetSum":25357,
 "sourceSum":0}
